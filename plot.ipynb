# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import mpld3
import os

# %%
#os.system('bazel-bin/threadpool > data.txt')
dataset = pd.read_csv('data.txt', sep='\n', comment='#', dtype=int)
dataset.tail()
# Out:
#       173
# 1018   13
# 1019   13
# 1020   12
# 1021   11
# 1022   10

# %%
dataset.describe().transpose()
# Out:
#       count        mean        std  min   25%    50%    75%    max
# 173  1023.0  111.030303  79.145856  0.0  45.0  107.0  166.0  354.0

# %%
mpld3.enable_notebook()

plt.ylim(int(info['min']), int(info['max']))
xmin, xmax = plt.xlim()
plt.xlabel('nth task')
plt.ylabel('delay (us)')
plt.plot(dataset)
#plt.legend()
plt.show()
